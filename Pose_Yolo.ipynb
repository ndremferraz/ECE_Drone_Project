# %% [markdown]
# <a href="https://colab.research.google.com/github/ndremferraz/ECE_Drone_Project/blob/main/Pose_Yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 33.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.7 MB/s eta 0:00:00
# ...

# %%
model = YOLO("yolo11n-pose.pt")

results = model.train(data="/content/drive/MyDrive/Egg_Pose_Labeled/data.yaml", epochs=200, imgsz=640, lrf=0.0025)
# Out:
# ...
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo pose predict model=runs/pose/train/weights/best.pt source=/content/drive/MyDrive/Egg_Pose_Labeled/valid/images save=True

import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/pose/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-pose summary (fused): 109 layers, 2,680,438 parameters, 0 gradients, 6.7 GFLOPs
#
# image 1/6 /content/drive/MyDrive/Egg_Pose_Labeled/valid/images/20250711121158_JPG.rf.a12a3b6b627f0287946c62a39f507828.jpg: 480x640 4 Eggs, 49.2ms
# image 2/6 /content/drive/MyDrive/Egg_Pose_Labeled/valid/images/20250711121509_JPG.rf.3ea1aa548eb6dfbf6ed9d6fbf0a39a74.jpg: 480x640 1 Egg, 9.6ms
# image 3/6 /content/drive/MyDrive/Egg_Pose_Labeled/valid/images/20250711124027_JPG.rf.027a3e521a3f51b3d0e589c4f3fca16e.jpg: 480x640 4 Eggs, 9.3ms
# image 4/6 /content/drive/MyDrive/Egg_Pose_Labeled/valid/images/20250718145736_jpg.rf.2ef492f21a97feef510a295f7d121224.jpg: 480x640 4 Eggs, 9.3ms
# image 5/6 /content/drive/MyDrive/Egg_Pose_Labeled/valid/images/20250718150752_jpg.rf.a6f636f36802c51dfd99dcd29f9e591d.jpg: 480x640 3 Eggs, 10.2ms
# ...

# %%
# !mkdir /content/my_model
# !cp /content/runs/pose/train/weights/best.pt /content/my_model/yolo11n_pose_aug17_2025.pt
# !cp -r /content/runs/pose/train/ /content/my_model

# %cd /content/my_model
# !zip /content/yolo11n_pose_aug17_2025.zip yolo11n_pose_aug17_2025.pt
# !zip -r /content/yolo11n_pose_aug17_2025.zip train
# %cd /content/

from google.colab import files
files.download('/content/yolo11n_pose_aug17_2025.zip')
# Out:
# /content/my_model
#   adding: yolo11n_pose_aug17_2025.pt (deflated 11%)
#   adding: train/ (stored 0%)
#   adding: train/train_batch1.jpg (deflated 4%)
#   adding: train/BoxF1_curve.png (deflated 18%)
#   adding: train/results.csv (deflated 63%)
#   adding: train/train_batch4940.jpg (deflated 10%)
#   adding: train/train_batch2.jpg (deflated 3%)
#   adding: train/train_batch4941.jpg (deflated 10%)
#   adding: train/weights/ (stored 0%)
#   adding: train/weights/best.pt (deflated 11%)
#   adding: train/weights/last.pt (deflated 11%)
#   adding: train/BoxPR_curve.png (deflated 30%)
#   adding: train/results.png (deflated 7%)
#   adding: train/PoseR_curve.png (deflated 19%)
#   adding: train/val_batch0_pred.jpg (deflated 14%)
#   adding: train/args.yaml (deflated 52%)
#   adding: train/labels_correlogram.jpg (deflated 39%)
#   adding: train/confusion_matrix.png (deflated 38%)
#   adding: train/PosePR_curve.png (deflated 30%)
#   adding: train/train_batch0.jpg (deflated 4%)
# ...
